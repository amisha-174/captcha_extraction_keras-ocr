# %%
# !pip install keras-ocr
# !pip install matplotlib
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import math, keras_ocr

# %%
image_path = "/content/Captcha1.jpg"

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Plot...
original_image = cv2.imread(image_path)
original_image = original_image[:, :, ::-1]
plt.imshow(original_image)

# %%
# !pip install tensorflow==2.15
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ...

# %%
# Initialize pipeline
pipeline = keras_ocr.pipeline.Pipeline()

# Read in image
read_image = keras_ocr.tools.read(image_path)

# prediction_groups is a list of (word, box) tuples
prediction_groups = pipeline.recognize([read_image])
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...
# 1/1 [==============================] - 3s 3s/step

# %%
keras_ocr.tools.drawAnnotations(image=read_image, predictions=prediction_groups[0])
# Out:
# <Axes: >

# %%
import zipfile
import os

# Define the path to the zip file and the directory to extract it to
zip_file_path = '/content/captcha_data.zip'
extract_to_dir = "/content/ext_file.zip"

# Ensure the extract directory exists
os.makedirs(extract_to_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_dir)

print(f"File unzipped successfully to {extract_to_dir}")
# Out:
# File unzipped successfully to /content/ext_file.zip

# %%
zip_file_path = "/content/captcha_data.zip"

# Open the zip file and list its contents
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Get the list of file names inside the zip file
    zip_contents = zip_ref.namelist()

# Print the list of files
for file_name in zip_contents:
    print(file_name)
# Out:
# captcha_data/
# captcha_data/s1/
# captcha_data/s1/Captcha0.jpg
# captcha_data/s1/Captcha1.jpg
# captcha_data/s1/Captcha10.jpg
# captcha_data/s1/Captcha11.jpg
# captcha_data/s1/Captcha12.jpg
# captcha_data/s1/Captcha13.jpg
# captcha_data/s1/Captcha14.jpg
# captcha_data/s1/Captcha15.jpg
# captcha_data/s1/Captcha16.jpg
# captcha_data/s1/Captcha17.jpg
# captcha_data/s1/Captcha18.jpg
# captcha_data/s1/Captcha19.jpg
# captcha_data/s1/Captcha2.jpg
# captcha_data/s1/Captcha20.jpg
# captcha_data/s1/Captcha21.jpg
# captcha_data/s1/Captcha22.jpg
# captcha_data/s1/Captcha23.jpg
# captcha_data/s1/Captcha24.jpg
# captcha_data/s1/Captcha3.jpg
# captcha_data/s1/Captcha4.jpg
# captcha_data/s1/Captcha5.jpg
# captcha_data/s1/Captcha6.jpg
# captcha_data/s1/Captcha7.jpg
# captcha_data/s1/Captcha8.jpg
# captcha_data/s1/Captcha9.jpg
# captcha_data/s2/
# captcha_data/s2/09ozexrf.png
# captcha_data/s2/3hwjr4bn.png
# captcha_data/s2/3m1vcthp.png
# captcha_data/s2/4jzire8o.png
# captcha_data/s2/7sw462sk.png
# ...

# %%
import os

# %%
def process_image(image_path):
    # Read the image
    read_image = keras_ocr.tools.read(image_path)

    # Check if image is None
    if read_image is None:
        print(f"Error loading image: {image_path}")
        return

    print(f"Image shape: {read_image.shape}, dtype: {read_image.dtype}")
    # The rest of your code...

    prediction_groups = pipeline.recognize([read_image])

    # Draw annotations on the image
    annotated_image = keras_ocr.tools.drawAnnotations(image=read_image, predictions=prediction_groups[0])

    # # Display the annotated image with recognized text
    # plt.imshow(annotated_image)
    # plt.axis('off')
    # plt.show()

    # Optionally, print the recognized text and bounding boxes
    for text, box in prediction_groups[0]:
        print(f"Detected text: {text}, Bounding box: {box}")

# Walk through the directories and process each image
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(root, file)
            print(f"Processing: {image_path}")
            process_image(image_path)
# Out:
# Processing: /content/ext_file.zip/captcha_data/s2/09ozexrf.png
# Image shape: (25, 65, 3), dtype: uint8
# ...
# 1/1 [==============================] - 0s 307ms/step
# Detected text: 362g15, Bounding box: [[ 4.  7.]
#  [61.  7.]
#  [61. 22.]
#  [ 4. 22.]]
# Processing: /content/ext_file.zip/captcha_data/s2/7sw462sk.png
# Image shape: (25, 65, 3), dtype: uint8
# ...
# 1/1 [==============================] - 0s 276ms/step
# Detected text: 781y47, Bounding box: [[ 4.  7.]
#  [60.  7.]
#  [60. 20.]
#  [ 4. 20.]]
# Processing: /content/ext_file.zip/captcha_data/s2/wr2nx7rh.png
# Image shape: (25, 65, 3), dtype: uint8
# ...
# 1/1 [==============================] - 0s 293ms/step
# Detected text: 8k86en, Bounding box: [[ 3.  7.]
#  [61.  7.]
#  [61. 21.]
#  [ 3. 21.]]
# Processing: /content/ext_file.zip/captcha_data/s2/fl3f8kgr.png
# Image shape: (25, 65, 3), dtype: uint8
# ...
# 1/1 [==============================] - 0s 268ms/step
# Detected text: y8526r, Bounding box: [[ 4.0628967  6.043891 ]
# ...
